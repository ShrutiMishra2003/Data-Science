# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df=pd.read_csv("C:\\Users\\Shruti Mishra\\Downloads\\canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.xlabel("year", fontsize=20)
plt.ylabel("per capita income", fontsize=20)
plt.scatter(df.year,df["per capita income (US$)"],color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["year"]],df["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\Shruti Mishra\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
plt.xlabel("year", fontsize=20)
plt.ylabel("per capita income", fontsize=20)
plt.scatter(df.year,df["per capita income (US$)"], color='red',marker='+')
plt.plot(df.year,reg.predict(df[["year"]]),color='blue')

# %%
reg.score(df[["year"]],df["per capita income (US$)"])
# Out:
# 0.890916917957032
