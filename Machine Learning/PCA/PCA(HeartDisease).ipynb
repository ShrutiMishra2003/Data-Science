# %%
import pandas as pd
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_17820\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Shruti Mishra\\Downloads\\heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
df.shape
# Out:
# (918, 12)

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
mean=df.RestingBP.mean()
mean
# Out:
# 132.39651416122004

# %%
std=df.RestingBP.std()
std
# Out:
# 18.5141541199078

# %%
df['zscore']=(df.RestingBP-df.RestingBP.mean())/df.RestingBP.std()
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore   zscores
# 0              N      0.0       Up             0  0.410685 -1.112508
# 1              N      1.0     Flat             1  1.490940 -0.112508
# 2              N      0.0       Up             0 -0.129442 -1.112508
# 3              Y      1.5     Flat             1  0.302660 -0.112508
# 4              N      0.0       Up             0  0.950812 -1.112508

# %%
df1=df.drop(['zscores'],axis='columns')
df1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore
# ...

# %%
df1.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease        zscore
# count  918.000000    918.000000  9.180000e+02
# mean     0.887364      0.553377  2.031781e-16
# std      1.066570      0.497414  1.000000e+00
# min     -2.600000      0.000000 -7.151097e+00
# 25%      0.000000      0.000000 -6.695696e-01
# 50%      0.600000      1.000000 -1.294423e-01
# ...

# %%
df1[df1.zscore>3]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore
# 109    106              N      0.0       Up             0  3.111322
# 241    142              Y      2.0     Flat             1  3.651449
# 365    140              Y      1.0     Flat             1  3.651449
# 399     70              N      0.0     Flat             1  3.651449
# ...

# %%
df1[df1.zscore<-3]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 449   55   M           NAP          0            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore
# 449    155              N      1.5     Flat             1 -7.151097

# %%
df1_no_outliers=df1[(df1.zscore<=3) & (df1.zscore>=-3)]
df1_no_outliers
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore
# ...

# %%
df1_no_outliers['zscores']=(df1.Cholesterol-df1.Cholesterol.mean())/df.Cholesterol.std()
df1_no_outliers
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_17820\2849479276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_no_outliers['zscores']=(df1.Cholesterol-df1.Cholesterol.mean())/df.Cholesterol.std()
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# ...

# %%
df1_no_outliers[df1_no_outliers.zscores>3]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore   zscores
# 76     130              N      0.0     Flat             1 -0.777595  3.018723
# 149    125              Y      1.0     Flat             1 -0.129442  3.695238
# 616    160              N      1.6     Flat             0 -0.939633  3.338696

# %%
df2_no_outliers=df1_no_outliers[(df1_no_outliers.zscores<=3) & (df1_no_outliers.zscores>=-3)]
df2_no_outliers
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore   zscores
# ...

# %%
df2_no_outliers['zscores1']=(df2_no_outliers.MaxHR-df2_no_outliers.MaxHR.mean())/df2_no_outliers.MaxHR.std()
df2_no_outliers
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_17820\92499567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_no_outliers['zscores1']=(df2_no_outliers.MaxHR-df2_no_outliers.MaxHR.mean())/df2_no_outliers.MaxHR.std()
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ...

# %%
df3_no_outliers=df2_no_outliers[(df2_no_outliers.zscores1<=3) & (df2_no_outliers.zscores1>=-3)]
df3_no_outliers
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore   zscores  \
# ...

# %%
df3_no_outliers['zscore2']=(df3_no_outliers.Oldpeak-df3_no_outliers.Oldpeak.mean())/df3_no_outliers.Oldpeak.std()
df3_no_outliers
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_17820\1943448999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_no_outliers['zscore2']=(df3_no_outliers.Oldpeak-df3_no_outliers.Oldpeak.mean())/df3_no_outliers.Oldpeak.std()
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ...

# %%
df4_no_outliers=df3_no_outliers[(df3_no_outliers.zscore2<=3) & (df3_no_outliers.zscore2>=-3)]
df4_no_outliers
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore   zscores  \
# ...

# %%
df4_no_outliers['zscore3']=(df4_no_outliers.Age-df4_no_outliers.Age.mean())/df4_no_outliers.Age.std()
df4_no_outliers
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_17820\4096961775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_no_outliers['zscore3']=(df4_no_outliers.Age-df4_no_outliers.Age.mean())/df4_no_outliers.Age.std()
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ...

# %%
df5_no_outliers=df4_no_outliers[(df4_no_outliers.zscore3<=3) & (df4_no_outliers.zscore3>=-3)]
df5_no_outliers
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease    zscore   zscores  \
# ...

# %%
df0=df5_no_outliers.drop(['zscore','zscores','zscores1','zscore2','zscore3'],axis='columns')
df0
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
dummies=pd.get_dummies(df0,drop_first=True)
dummies=dummies.astype(int)
dummies.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172        0             0
# 1   49        160          180          0    156        1             1
# 2   37        130          283          0     98        0             0
# 3   48        138          214          0    108        1             1
# 4   54        150          195          0    122        0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
X=dummies.drop(['HeartDisease'],axis='columns')
y=dummies.HeartDisease
scaler=StandardScaler()
X_scale=scaler.fit_transform(X)
X_scale
# Out:
# array([[-1.42815446,  0.46590022,  0.84963584, ..., -0.8229452 ,
#         -0.99888827,  1.13469459],
#        [-0.47585532,  1.63471366, -0.16812204, ..., -0.8229452 ,
#          1.00111297, -0.88129441],
#        [-1.7455875 , -0.1185065 ,  0.79361247, ..., -0.8229452 ,
#         -0.99888827,  1.13469459],
#        ...,
#        [ 0.3706328 , -0.1185065 , -0.62564622, ...,  1.21514774,
#          1.00111297, -0.88129441],
#        [ 0.3706328 , -0.1185065 ,  0.35476274, ..., -0.8229452 ,
#          1.00111297, -0.88129441],
#        [-1.63977649,  0.34901888, -0.21480818, ..., -0.8229452 ,
#         -0.99888827,  1.13469459]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scale,y,test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC(gamma='auto',kernel='linear')
model.fit(X_train,y_train)
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
model.score(X_test,y_test)
# Out:
# 0.8833333333333333

# %%
from sklearn.decomposition import PCA
pca=PCA(0.95)
x_pca=pca.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x_pca,y,test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC(gamma='auto',kernel='linear')
model.fit(X_train,y_train)
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
model.score(X_test,y_test)
# Out:
# 0.7277777777777777

# %%
len(X_train)
# Out:
# 719
