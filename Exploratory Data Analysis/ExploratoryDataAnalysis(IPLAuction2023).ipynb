# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\Shruti Mishra\\Downloads\\archive (4)\\iplauction2023.csv")
df
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
df.shape
# Out:
# (309, 7)

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            151.000000             238.000000
# mean              59.205298             368.067227
# std               59.688337             449.070117
# min               20.000000              20.000000
# 25%               20.000000              21.250000
# 50%               20.000000             150.000000
# 75%               75.000000             625.000000
# max              200.000000            1850.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.dtypes
# Out:
# name                      object
# player style              object
# nationality               object
# base price (in lacs)     float64
# final price (in lacs)    float64
# franchise                 object
# status                    object
# dtype: object

# %%
df.nunique()
# Out:
# name                     309
# player style               4
# nationality               14
# base price (in lacs)       8
# final price (in lacs)     67
# franchise                 10
# status                     3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                 71
# status                     0
# dtype: int64

# %%
df["base price (in lacs)"].fillna(0, inplace= True)
df.isnull().sum()
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_20740\3271695380.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["base price (in lacs)"].fillna(0, inplace= True)
# name                      0
# player style              0
# nationality               0
# base price (in lacs)      0
# final price (in lacs)    71
# franchise                71
# status                    0
# dtype: int64

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   0.0
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df["final price (in lacs)"].fillna(0, inplace= True)
df.isnull().sum()
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_20740\2820892273.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["final price (in lacs)"].fillna(0, inplace= True)
# name                      0
# player style              0
# nationality               0
# base price (in lacs)      0
# final price (in lacs)     0
# franchise                71
# status                    0
# dtype: int64

# %%
df["franchise"].fillna("no franchise", inplace= True)
df.isnull().sum()
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_20740\2841894629.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["franchise"].fillna("no franchise", inplace= True)
# name                     0
# player style             0
# nationality              0
# base price (in lacs)     0
# final price (in lacs)    0
# franchise                0
# status                   0
# dtype: int64

# %%
mean=df["base price (in lacs)"].mean()
std=df["base price (in lacs)"].std()
mean,std
# Out:
# (28.932038834951456, 51.125246413388126)

# %%
std1=df["final price (in lacs)"].std()
mean1=df["final price (in lacs)"].mean()
std1,mean1
# Out:
# (423.3557775965867, 283.49514563106794)

# %%
df["zscore"]=(df["base price (in lacs)"]-df["base price (in lacs)"].mean())/df["base price (in lacs)"].std()
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   0.0
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs)     franchise    status    zscore
# 0                   20.0           KKR  RETAINED -0.565905
# 1                    0.0  no franchise    UNSOLD -0.174709
# 2                    0.0  no franchise    UNSOLD  0.901080
# 3                  150.0           KKR      SOLD  2.368066
# 4                  100.0            RR      SOLD  1.390076

# %%
df[df.zscore>3]
# Out:
#                       name player style   nationality  base price (in lacs)  \
# 17   Rassie van der Dussen       Batter  South Africa                 200.0
# 26           Rilee Rossouw       Batter  South Africa                 200.0
# 59           Jamie Overton   Allrounder       England                 200.0
# 87           James Neesham   Allrounder   New Zealand                 200.0
# 93             Travis Head   Allrounder     Australia                 200.0
# 129        Kane Williamson       Batter   New Zealand                 200.0
# 132           Jason Holder   Allrounder   West Indies                 200.0
# 136        Nicholas Pooran    WK-Batter   West Indies                 200.0
# 139            Adil Rashid       Bowler       England                 200.0
# 141             Adam Milne       Bowler   New Zealand                 200.0
# 143           Chris Jordan       Bowler       England                 200.0
# ...

# %%
df_no_outliers=df[(df.zscore<=3) & (df.zscore>=-3)]
df_no_outliers
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   0.0
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   0.0
# 305        Moeen Ali   Allrounder       England                   0.0
# 306  Ruturaj Gaikwad       Batter         India                   0.0
# 307     Rishabh Pant    WK-Batter         India                   0.0
# 308       Axar Patel   Allrounder         India                   0.0
#
#      final price (in lacs)     franchise    status    zscore
# 0                     20.0           KKR  RETAINED -0.565905
# ...

# %%
df_no_outliers["zscore_2"]=(df_no_outliers["final price (in lacs)"]-df_no_outliers["final price (in lacs)"].mean())/df_no_outliers["final price (in lacs)"].std()
df_no_outliers
# Out:
# C:\Users\Shruti Mishra\AppData\Local\Temp\ipykernel_20740\763390436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers["zscore_2"]=(df_no_outliers["final price (in lacs)"]-df_no_outliers["final price (in lacs)"].mean())/df_no_outliers["final price (in lacs)"].std()
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   0.0
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ...

# %%
df_no_outliers[df_no_outliers.zscore_2>3]
# Out:
#                 name player style  nationality  base price (in lacs)  \
# 230     Ishan Kishan    WK-Batter        India                   0.0
# 282      Virat Kohli       Batter        India                   0.0
# 290     Rohit Sharma       Batter        India                   0.0
# 292         KL Rahul    WK-Batter        India                   0.0
# 296  Ravindra Jadeja   Allrounder        India                   0.0
# 300      Rashid Khan       Bowler  Afghanistan                   0.0
# 301    Hardik Pandya   Allrounder        India                   0.0
# 307     Rishabh Pant    WK-Batter        India                   0.0
#
#      final price (in lacs) franchise    status    zscore  zscore 2  zscore_2
# 230                 1525.0        MI  RETAINED -0.565905  3.150989  3.150989
# 282                 1500.0       RCB  RETAINED -0.565905  3.088215  3.088215
# 290                 1600.0        MI  RETAINED -0.565905  3.339310  3.339310
# ...

# %%
df_no_outliers_2=df_no_outliers[(df_no_outliers.zscore_2<=3) & (df_no_outliers.zscore_2>=-3)]
df_no_outliers_2
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   0.0
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 303     Prithvi Shaw       Batter         India                   0.0
# 304         MS Dhoni    WK-Batter         India                   0.0
# 305        Moeen Ali   Allrounder       England                   0.0
# 306  Ruturaj Gaikwad       Batter         India                   0.0
# 308       Axar Patel   Allrounder         India                   0.0
#
#      final price (in lacs)     franchise    status    zscore  zscore 2  \
# ...

# %%
plt.hist(df_no_outliers_2["base price (in lacs)"])
# Out:
# (array([150.,  82.,   3.,  26.,   0.,   4.,  12.,   0.,   0.,   8.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_no_outliers_2["final price (in lacs)"])
# Out:
# (array([179.,  26.,  17.,  10.,  13.,  18.,   8.,   6.,   5.,   3.]),
#  array([   0.,  140.,  280.,  420.,  560.,  700.,  840.,  980., 1120.,
#         1260., 1400.]),
#  <BarContainer object of 10 artists>)

# %%
xpose=np.arange(len(["final price (in lacs)"]))
xpose
# Out:
# array([0])

# %%
plt.scatter(x=df_no_outliers_2["base price (in lacs)"],y=df_no_outliers_2["final price (in lacs)"])
